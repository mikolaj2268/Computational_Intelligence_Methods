# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from joblib import Parallel, delayed

class Rectangle:
    def __init__(self, width, height, value):
        self.width = width
        self.height = height
        self.value = value

class Solution:
    def __init__(self, circle_radius):
        self.circle_radius = circle_radius
        self.rectangles = []
        self.positions = []
        self.total_value = 0

    def add_rectangle(self, rectangle, position):
        if self.is_valid_position(rectangle, position):
            self.rectangles.append(rectangle)
            self.positions.append(position)
            self.total_value += rectangle.value

    def is_valid_position(self, rectangle, position):
        x, y = position
        corners = [
            (x, y),
            (x + rectangle.width, y),
            (x, y + rectangle.height),
            (x + rectangle.width, y + rectangle.height)
        ]
        if any(cx**2 + cy**2 > self.circle_radius**2 for cx, cy in corners):
            return False
        for i, rect in enumerate(self.rectangles):
            rx, ry = self.positions[i]
            if not (x + rectangle.width <= rx or x >= rx + rect.width or
                    y + rectangle.height <= ry or y >= ry + rect.height):
                return False
        return True

class GeneticAlgorithm:
    def __init__(self, data, circle_radius, population_size=50, generations=100, mutation_rate=0.2):
        self.rectangles = [Rectangle(row.width, row.height, row.value) for _, row in data.iterrows()]
        self.circle_radius = circle_radius
        self.population_size = population_size
        self.generations = generations
        self.mutation_rate = mutation_rate
        self.population = self.initialize_population()

    def initialize_population(self):
        population = []
        for _ in range(self.population_size):
            solution = Solution(self.circle_radius)
            for rectangle in sorted(self.rectangles, key=lambda rect: rect.value, reverse=True):
                for _ in range(100):
                    x, y = random.uniform(-self.circle_radius, self.circle_radius - rectangle.width), random.uniform(-self.circle_radius, self.circle_radius - rectangle.height)
                    if solution.is_valid_position(rectangle, (x, y)):
                        solution.add_rectangle(rectangle, (x, y))
                        break
            population.append(solution)
        return population

    def generate_valid_position(self, rectangle):
        for _ in range(100): 
            x = random.uniform(-self.circle_radius, self.circle_radius - rectangle.width)
            y = random.uniform(-self.circle_radius, self.circle_radius - rectangle.height)
            if self.is_within_circle(x, y, rectangle):
                return (x, y)
        return (0, 0)  # Return a default position if no valid position is found

    def is_within_circle(self, x, y, rectangle):
        corners = [
            (x, y),
            (x + rectangle.width, y),
            (x, y + rectangle.height),
            (x + rectangle.width, y + rectangle.height)
        ]
        for cx, cy in corners:
            if cx**2 + cy**2 > self.circle_radius**2:
                return False
        return True

    def fitness(self, solution):
        return solution.total_value

    def selection(self):
        sorted_population = sorted(self.population, key=self.fitness, reverse=True)
        return sorted_population[:self.population_size // 2]

    def crossover(self, parent1, parent2):
        child = Solution(self.circle_radius)
        for i in range(max(len(parent1.rectangles), len(parent2.rectangles))):
            if i < len(parent1.rectangles) and random.random() < 0.5 and child.is_valid_position(parent1.rectangles[i], parent1.positions[i]):
                child.add_rectangle(parent1.rectangles[i], parent1.positions[i])
            elif i < len(parent2.rectangles) and child.is_valid_position(parent2.rectangles[i], parent2.positions[i]):
                child.add_rectangle(parent2.rectangles[i], parent2.positions[i])
        return child

    def mutate(self, solution):
        for i in range(len(solution.rectangles)):
            if random.random() < self.mutation_rate:
                if random.random() < 0.5:  # 50% chance to mutate an existing rectangle
                    for _ in range(10):  # Try 10 times to mutate to a valid position
                        x, y = self.generate_valid_position(solution.rectangles[i])
                        if solution.is_valid_position(solution.rectangles[i], (x, y)):
                            solution.positions[i] = (x, y)
                            break
                else:  # 50% chance to add a new rectangle
                    rectangle = random.choice(self.rectangles)
                    for _ in range(10):  # Try 10 times to add at a valid position
                        x, y = self.generate_valid_position(rectangle)
                        if solution.is_valid_position(rectangle, (x, y)):
                            solution.add_rectangle(rectangle, (x, y))
                            break

    def run(self):
        best_solution = None
        best_solution_value = 0

        for generation in range(self.generations):
            selected_population = self.selection()
            new_population = selected_population.copy()
            
            while len(new_population) < self.population_size:
                parent1 = random.choice(selected_population)
                parent2 = random.choice(selected_population)
                child = self.crossover(parent1, parent2)
                self.mutate(child)
                new_population.append(child)
            
            self.population = new_population

            # Calculate the fitness value for each solution
            fitness_values = Parallel(n_jobs=-1)(delayed(self.fitness)(sol) for sol in self.population)
            best_solution_index = np.argmax(fitness_values)
            current_best_solution = self.population[best_solution_index]

            if current_best_solution.total_value > best_solution_value:
                best_solution = current_best_solution
                best_solution_value = current_best_solution.total_value

            # Print the best solution value after each generation
            print(f'Generation {generation}, Best Solution Value: {best_solution_value}')

            # Adjust the mutation rate
            if generation > 0 and generation % 100 == 0:
                self.mutation_rate *= 0.8
        
        # Visualize the best solution at the end
        self.visualize(best_solution)
        return best_solution

    def visualize(self, solution):
        fig, ax = plt.subplots()
        circle = plt.Circle((0, 0), self.circle_radius, color='r', fill=False)
        ax.add_artist(circle)
        
        for rect, (x, y) in zip(solution.rectangles, solution.positions):
            if self.is_within_circle(x, y, rect):
                ax.add_patch(plt.Rectangle((x, y), rect.width, rect.height, fill=True, edgecolor='b', facecolor='b', alpha=0.5))
                print(f'Rectangle at ({x}, {y}) with width {rect.width} and height {rect.height}')
        
        ax.set_xlim(-self.circle_radius, self.circle_radius)
        ax.set_ylim(-self.circle_radius, self.circle_radius)
        ax.set_aspect('equal', 'box')
        plt.title(f"Total Value: {solution.total_value}")
        plt.show()

# Load data from CSV files
file_paths = ["../data/r800.csv", "../data/r850.csv", "../data/r1000.csv", "../data/r1100.csv", "../data/r1200.csv"]
data = {int(file_path.split('/')[-1].split('.')[0][1:]): pd.read_csv(file_path, header=None, names=['width', 'height', 'value']) for file_path in file_paths}

# Run genetic algorithm for specific circle radii
results = {}
for radius in [800, 850, 1000, 1100, 1200]:
    print(f'Running Genetic Algorithm for circle radius {radius}')
    ga = GeneticAlgorithm(data[radius], radius)
    best_solution = ga.run()
    results[radius] = best_solution.total_value

# Display results
for radius, value in results.items():
    print(f'Circle Radius: {radius}, Best Solution Value: {value}')
# Out:
# Running Genetic Algorithm for circle radius 800
# Generation 0, Best Solution Value: 2940
# Generation 1, Best Solution Value: 2940
# Generation 2, Best Solution Value: 3000
# Generation 3, Best Solution Value: 3440
# Generation 4, Best Solution Value: 4380
# Generation 5, Best Solution Value: 4600
# Rectangle at (-640.3399882865477, -47.3132087759991) with width 10 and height 120
# Rectangle at (262.38645887958205, 536.2380885442101) with width 300 and height 30
# Rectangle at (-740.1892273950043, -148.38484555028094) with width 300 and height 30
# Rectangle at (-173.5724287345073, 280.7479921348663) with width 300 and height 30
# Rectangle at (115.83142378631521, 583.1494685078201) with width 400 and height 20
# Rectangle at (-686.8626741719308, -111.51384424062337) with width 120 and height 10
# Rectangle at (169.69613089116058, -36.46185445697813) with width 400 and height 20
# Rectangle at (-619.883870186141, 564.8329032022073) with width 120 and height 10
# Rectangle at (-486.6981397361575, 486.8143169783566) with width 10 and height 120
# Rectangle at (-551.0330808471587, 615.5463102871524) with width 400 and height 20
# Rectangle at (-756.7514744757377, 351.2427642152529) with width 400 and height 20
# Rectangle at (622.124701488458, -132.60141367818392) with width 10 and height 120
# Rectangle at (-388.9611442939442, -709.0334795284883) with width 400 and height 20
# Rectangle at (437.3384572678467, 27.11307582169161) with width 300 and height 30
# Rectangle at (-723.8011838100555, 406.20298526170836) with width 400 and height 20
# Rectangle at (283.43201357014823, 606.7312125478793) with width 120 and height 10
# Rectangle at (447.4119973881227, 420.6202108767204) with width 120 and height 10
# Rectangle at (680.046409832283, 154.9738815407859) with width 10 and height 120
# Rectangle at (114.73933417802789, 411.05365243038614) with width 300 and height 30
# Rectangle at (-77.55037730154459, -356.091599629682) with width 300 and height 30
# Rectangle at (673.0035172479652, -303.76689852303616) with width 120 and height 120
# Rectangle at (240.55649035768693, -410.4901234547596) with width 400 and height 20
# Rectangle at (700.6222807466054, 136.6788062774143) with width 120 and height 10
# Rectangle at (-90.92674399833834, 28.467840655153054) with width 10 and height 120
# Running Genetic Algorithm for circle radius 1000
# Generation 0, Best Solution Value: 1740
# Generation 1, Best Solution Value: 1740
# Generation 2, Best Solution Value: 2040
# Generation 3, Best Solution Value: 2140
# Generation 4, Best Solution Value: 2540
# Generation 5, Best Solution Value: 3740
# Generation 6, Best Solution Value: 3780
# Generation 7, Best Solution Value: 4040
# Generation 8, Best Solution Value: 4060
# Generation 9, Best Solution Value: 4600
# Generation 10, Best Solution Value: 5960
# Generation 11, Best Solution Value: 6360
# Generation 12, Best Solution Value: 6620
# Generation 13, Best Solution Value: 6920
# Generation 14, Best Solution Value: 7420
# Generation 15, Best Solution Value: 8120
# Generation 16, Best Solution Value: 8120
# Generation 17, Best Solution Value: 8420
# Generation 18, Best Solution Value: 9000
# Generation 19, Best Solution Value: 9420
# Generation 20, Best Solution Value: 9420
# Generation 21, Best Solution Value: 9420
# Generation 22, Best Solution Value: 10200
# Generation 23, Best Solution Value: 10860
# Generation 24, Best Solution Value: 10860
# Generation 25, Best Solution Value: 10860
# Generation 26, Best Solution Value: 10860
# Generation 27, Best Solution Value: 11600
# Generation 28, Best Solution Value: 11780
# Generation 29, Best Solution Value: 11880
# Generation 30, Best Solution Value: 11880
# Generation 31, Best Solution Value: 11880
# Generation 32, Best Solution Value: 12320
# Generation 33, Best Solution Value: 12320
# Generation 34, Best Solution Value: 12320
# Generation 35, Best Solution Value: 12420
# Generation 36, Best Solution Value: 12620
# Generation 37, Best Solution Value: 13020
# Generation 38, Best Solution Value: 13440
# Generation 39, Best Solution Value: 13440
# Generation 40, Best Solution Value: 13440
# Generation 41, Best Solution Value: 13440
# Generation 42, Best Solution Value: 13540
# Generation 43, Best Solution Value: 13700
# Generation 44, Best Solution Value: 13720
# Generation 45, Best Solution Value: 13720
# Generation 46, Best Solution Value: 13920
# Generation 47, Best Solution Value: 13960
# Generation 48, Best Solution Value: 14000
# Generation 49, Best Solution Value: 14200
# Generation 50, Best Solution Value: 14200
# Generation 51, Best Solution Value: 14580
# Generation 52, Best Solution Value: 14580
# Generation 53, Best Solution Value: 14700
# Generation 54, Best Solution Value: 14900
# Generation 55, Best Solution Value: 14900
# Generation 56, Best Solution Value: 14940
# Generation 57, Best Solution Value: 14940
# Generation 58, Best Solution Value: 14980
# Generation 59, Best Solution Value: 15360
# Generation 60, Best Solution Value: 15480
# Generation 61, Best Solution Value: 15680
# Generation 62, Best Solution Value: 15720
# Generation 63, Best Solution Value: 15720
# Generation 64, Best Solution Value: 15920
# Generation 65, Best Solution Value: 16100
# Generation 66, Best Solution Value: 16100
# Generation 67, Best Solution Value: 16400
# Generation 68, Best Solution Value: 16440
# Generation 69, Best Solution Value: 16440
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 180
#     178     print(f'Running Genetic Algorithm for circle radius {radius}')
#     179     ga = GeneticAlgorithm(data[radius], radius)
# --> 180     best_solution = ga.run()
#     181     results[radius] = best_solution.total_value
#     183 # Display results
#
# Cell In[18], line 130, in GeneticAlgorithm.run(self)
#     128     parent2 = random.choice(selected_population)
#     129     child = self.crossover(parent1, parent2)
# --> 130     self.mutate(child)
#     131     new_population.append(child)
#     133 self.population = new_population
#
# Cell In[18], line 106, in GeneticAlgorithm.mutate(self, solution)
#     104 if random.random() < 0.5:  # 50% chance to mutate an existing rectangle
#     105     for _ in range(10):  # Try 10 times to mutate to a valid position
# --> 106         x, y = self.generate_valid_position(solution.rectangles[i])
#     107         if solution.is_valid_position(solution.rectangles[i], (x, y)):
#     108             solution.positions[i] = (x, y)
#
# Cell In[18], line 69, in GeneticAlgorithm.generate_valid_position(self, rectangle)
#      67     x = random.uniform(-self.circle_radius, self.circle_radius - rectangle.width)
#      68     y = random.uniform(-self.circle_radius, self.circle_radius - rectangle.height)
# ---> 69     if self.is_within_circle(x, y, rectangle):
#      70         return (x, y)
#      71 return (0, 0)
#
# Cell In[18], line 73, in GeneticAlgorithm.is_within_circle(self, x, y, rectangle)
#      70             return (x, y)
#      71     return (0, 0)  # Return a default position if no valid position is found
# ---> 73 def is_within_circle(self, x, y, rectangle):
#      74     corners = [
#      75         (x, y),
#      76         (x + rectangle.width, y),
#      77         (x, y + rectangle.height),
#      78         (x + rectangle.width, y + rectangle.height)
#      79     ]
#      80     for cx, cy in corners:
#
# KeyboardInterrupt:
